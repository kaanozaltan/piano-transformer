# %% [markdown]
# # Usage Demo :

# %%
import copy
import glob
import numpy as np
import pretty_midi
import seaborn as sns
import matplotlib.pyplot as plt
from piano_transformer.mgeval import core, utils
from sklearn.model_selection import LeaveOneOut
from tqdm import tqdm

# %% [markdown]
# ## Absolute measurement: statistic analysis

# %% [markdown]
# Assign dataset path

# %%
from piano_transformer.utils.metrics import analyze_dataset_mgeval

analyze_dataset_mgeval("../experiments/mistral-62M_remi_maestro_v2/output/generated/", max_samples=100)
# Out:
# running full function
# ...

# %%
from piano_transformer.utils.metrics import comparing_pairwise_distances_mgeval

comparing_pairwise_distances_mgeval("../experiments/mistral-62M_remi_maestro_v2/output/train/", "../experiments/mistral-62M_remi_maestro_v2/output/generated/", "graphics_62M_subset_debug", max_samples=100)
# Out:
# running full function
# Evaluating total_used_pitch on dataset1: 100%|██████████| 100/100 [00:04<00:00, 22.43it/s]
# Evaluating total_pitch_class_histogram on dataset1: 100%|██████████| 100/100 [00:04<00:00, 20.05it/s]
# ...
# Evaluating note_length_hist on dataset1: 100%|██████████| 100/100 [00:03<00:00, 28.35it/s]
# Evaluating note_length_transition_matrix on dataset1: 100%|██████████| 100/100 [00:03<00:00, 29.26it/s]
# Evaluating total_used_pitch on dataset2: 100%|██████████| 100/100 [00:03<00:00, 32.08it/s]
# Evaluating total_pitch_class_histogram on dataset2: 100%|██████████| 100/100 [00:04<00:00, 20.27it/s]
# ...
# Evaluating note_length_hist on dataset2: 100%|██████████| 100/100 [00:01<00:00, 60.45it/s]
# Evaluating note_length_transition_matrix on dataset2: 100%|██████████| 100/100 [00:01<00:00, 62.79it/s]
# Computing intra-set distances for total_used_pitch on dataset1: 100it [00:00, 3977.45it/s]
# ...

# %%
from piano_transformer.utils.metrics import fmd

fmd("../experiments/mistral-62M_remi_maestro_v2/output/train_subset", "../experiments/mistral-162M_remi_maestro_v1/output/generated_subset")
# Out:
# Loading files from ../experiments/mistral-162M_remi_maestro_v1/output/generated_subset
# ...
# Extracting features: 100%|██████████| 50/50 [00:02<00:00, 19.11it/s]
# 273.3223163831434

# %%
set1 = glob.glob('experiments/mistral-62M_remi_maestro_v2/output/train/*.midi')
print(set1)
print(len(set1))
set1 = set1[:25]
# Out:
# ['experiments/mistral-62M_remi_maestro_v2/output/train\\0_prompt.midi', 'experiments/mistral-62M_remi_maestro_v2/output/train\\10000_prompt.midi', 'experiments/mistral-62M_remi_maestro_v2/output/train\\10001_prompt.midi', 'experiments/mistral-62M_remi_maestro_v2/output/train\\10002_prompt.midi', 'experiments/mistral-62M_remi_maestro_v2/output/train\\10003_prompt.midi', 'experiments/mistral-62M_remi_maestro_v2/output/train\\10004_prompt.midi', 'experiments/mistral-62M_remi_maestro_v2/output/train\\10005_prompt.midi', 'experiments/mistral-62M_remi_maestro_v2/output/train\\10006_prompt.midi', 'experiments/mistral-62M_remi_maestro_v2/output/train\\10007_prompt.midi', 'experiments/mistral-62M_remi_maestro_v2/output/train\\10008_prompt.midi', 'experiments/mistral-62M_remi_maestro_v2/output/train\\10009_prompt.midi', 'experiments/mistral-62M_remi_maestro_v2/output/train\\1000_prompt.midi', 'experiments/mistral-62M_remi_maestro_v2/output/train\\10010_prompt.midi', 'experiments/mistral-62M_re
# ...

# %% [markdown]
# construct empty dictionary to fill in measurement across samples

# %%
num_samples = len(set1)

set_eval_init = {'total_used_pitch':np.zeros((num_samples,1)),
                 'total_used_note':np.zeros((num_samples,1)),
                 'total_pitch_class_histogram':np.zeros((num_samples,12)),
                 'pitch_range':np.zeros((num_samples,1)),
                 'avg_pitch_shift':np.zeros((num_samples,1))}

set1_eval = copy.deepcopy(set_eval_init)
metrics_list = list(set1_eval.keys())
kwargs = [{}, {"track_num": 0}, {}, {}, {"track_num": 0}]
for j in range(len(metrics_list)):
    for i in tqdm(range(0, num_samples), desc=f"Evaluating {metrics_list[j]}"):
        feature = core.extract_feature(set1[i])
        set1_eval[metrics_list[j]][i] = getattr(core.metrics(), metrics_list[j])(feature, **kwargs[j])
# Out:
# ...
# Evaluating avg_pitch_shift: 100%|██████████| 25/25 [00:00<00:00, 26.74it/s]

# %% [markdown]
# repeat for second dataset

# %%
set2 = glob.glob('experiments/mistral-62M_remi_maestro_v2/output/generated/*.midi')
print(set2)
print(len(set2))
set2 = set2[:25]
num_samples = len(set2)
set2_eval = copy.deepcopy(set_eval_init)

for j in range(len(metrics_list)):
    for i in tqdm(range(0, num_samples), desc=f"Evaluating {metrics_list[j]} on generated set"):
        feature = core.extract_feature(set2[i])
        try:
            set2_eval[metrics_list[j]][i] = getattr(core.metrics(), metrics_list[j])(feature, **kwargs[j])
        except Exception as e:
            print(f"Error evaluating {metrics_list[j]} for {set2[i]}: {e}")
# Out:
# ['experiments/mistral-62M_remi_maestro_v2/output/generated\\0_generated.midi', 'experiments/mistral-62M_remi_maestro_v2/output/generated\\10000_generated.midi', 'experiments/mistral-62M_remi_maestro_v2/output/generated\\10001_generated.midi', 'experiments/mistral-62M_remi_maestro_v2/output/generated\\10002_generated.midi', 'experiments/mistral-62M_remi_maestro_v2/output/generated\\10003_generated.midi', 'experiments/mistral-62M_remi_maestro_v2/output/generated\\10004_generated.midi', 'experiments/mistral-62M_remi_maestro_v2/output/generated\\10005_generated.midi', 'experiments/mistral-62M_remi_maestro_v2/output/generated\\10006_generated.midi', 'experiments/mistral-62M_remi_maestro_v2/output/generated\\10007_generated.midi', 'experiments/mistral-62M_remi_maestro_v2/output/generated\\10008_generated.midi', 'experiments/mistral-62M_remi_maestro_v2/output/generated\\10009_generated.midi', 'experiments/mistral-62M_remi_maestro_v2/output/generated\\1000_generated.midi', 'experiments/mistr
# ...

# %% [markdown]
# statistic analysis: absolute measurement

# %%
for i in range(0, len(metrics_list)):
    print(metrics_list[i] + ':')
    print('------------------------')
    print('reference_set')
    print('mean: ', np.mean(set1_eval[metrics_list[i]], axis=0))
    print('std: ', np.std(set1_eval[metrics_list[i]], axis=0))

    print('------------------------')
    print('generated_set')
    print('mean: ', np.mean(set2_eval[metrics_list[i]], axis=0))
    print('std: ', np.std(set2_eval[metrics_list[i]], axis=0))
# Out:
# total_used_pitch:
# ------------------------
# reference_set
# mean:  [55.225]
# std:  [10.12681465]
# ------------------------
# generated_set
# mean:  [38.578]
# std:  [11.98965871]
# total_used_note:
# ------------------------
# reference_set
# mean:  [610.32]
# std:  [60.41530932]
# ------------------------
# generated_set
# mean:  [424.025]
# std:  [138.44624363]
# total_pitch_class_histogram:
# ------------------------
# reference_set
# mean:  [0.09130021 0.07131033 0.09927384 0.07504826 0.08891903 0.08423048
#  0.06801368 0.10138821 0.076004   0.08770804 0.07991551 0.07688842]
# std:  [0.05763434 0.05626486 0.06234427 0.05917675 0.06331597 0.05603242
#  0.05015316 0.06482976 0.0592878  0.06031363 0.06012222 0.05269164]
# ------------------------
# generated_set
# mean:  [0.05618276 0.09783818 0.07819598 0.0697347  0.11054407 0.05406171
#  0.11336898 0.063506   0.0825525  0.09493548 0.05863614 0.1184435 ]
# ...

# %% [markdown]
# ## Relative measurement: generalizes the result among features with various dimensions

# %% [markdown]
# the features are sum- marized to
# - the intra-set distances
# - the difference of intra-set and inter-set distances.

# %% [markdown]
# exhaustive cross-validation for intra-set distances measurement

# %%
loo = LeaveOneOut()
loo.get_n_splits(np.arange(num_samples))
set1_intra = np.zeros((num_samples, len(metrics_list), num_samples-1))
set2_intra = np.zeros((num_samples, len(metrics_list), num_samples-1))
for i in range(len(metrics_list)):
    for train_index, test_index in tqdm(loo.split(np.arange(num_samples)), desc=f"Computing intra-set distances for {metrics_list[i]}"):
        set1_intra[test_index[0]][i] = utils.c_dist(set1_eval[metrics_list[i]][test_index], set1_eval[metrics_list[i]][train_index])
        set2_intra[test_index[0]][i] = utils.c_dist(set2_eval[metrics_list[i]][test_index], set2_eval[metrics_list[i]][train_index])
# Out:
# Computing intra-set distances for total_used_pitch: 25it [00:00, 6092.12it/s]
# Computing intra-set distances for total_used_note: 25it [00:00, 4394.33it/s]
# Computing intra-set distances for total_pitch_class_histogram: 25it [00:00, 4084.51it/s]
# Computing intra-set distances for pitch_range: 25it [00:00, 4164.16it/s]
# Computing intra-set distances for avg_pitch_shift: 25it [00:00, 10065.04it/s]

# %% [markdown]
# exhaustive cross-validation for inter-set distances measurement

# %%
loo = LeaveOneOut()
loo.get_n_splits(np.arange(num_samples))
sets_inter = np.zeros((num_samples, len(metrics_list), num_samples))

for i in range(len(metrics_list)):
    for train_index, test_index in tqdm(loo.split(np.arange(num_samples)), desc=f"Computing inter-set distances for {metrics_list[i]}"):
        sets_inter[test_index[0]][i] = utils.c_dist(set1_eval[metrics_list[i]][test_index], set2_eval[metrics_list[i]])
# Out:
# Computing inter-set distances for total_used_pitch: 1000it [00:02, 360.88it/s]
# Computing inter-set distances for total_used_note: 1000it [00:02, 355.24it/s]
# Computing inter-set distances for total_pitch_class_histogram: 1000it [00:02, 377.32it/s]
# Computing inter-set distances for pitch_range: 1000it [00:02, 360.57it/s]
# Computing inter-set distances for avg_pitch_shift: 1000it [00:02, 352.81it/s]

# %% [markdown]
# visualization of intra-set and inter-set distances

# %%
plot_set1_intra = np.transpose(set1_intra,(1, 0, 2)).reshape(len(metrics_list), -1)
plot_set2_intra = np.transpose(set2_intra,(1, 0, 2)).reshape(len(metrics_list), -1)
plot_sets_inter = np.transpose(sets_inter,(1, 0, 2)).reshape(len(metrics_list), -1)
for i in range(0,len(metrics_list)):
    sns.kdeplot(plot_set1_intra[i], label='intra_set1')
    sns.kdeplot(plot_sets_inter[i], label='inter')
    sns.kdeplot(plot_set2_intra[i], label='intra_set2')

    plt.title(metrics_list[i])
    plt.xlabel('Euclidean distance')
    plt.legend()
    plt.show()

# %% [markdown]
# the difference of intra-set and inter-set distances.

# %%
for i in range(0, len(metrics_list)):
    print( metrics_list[i] + ':')
    print('------------------------')
    print('reference_set')
    print('Kullback–Leibler divergence:',utils.kl_dist(plot_set1_intra[i], plot_sets_inter[i]))
    print('Overlap area:', utils.overlap_area(plot_set1_intra[i], plot_sets_inter[i]))
    
    print('generated_set')
    print('Kullback–Leibler divergence:',utils.kl_dist(plot_set2_intra[i], plot_sets_inter[i]))
    print('Overlap area:', utils.overlap_area(plot_set2_intra[i], plot_sets_inter[i]))
# Out:
# total_used_pitch:
# ------------------------
# reference_set
# Kullback–Leibler divergence: 0.008728857881875345
# Overlap area: 0.7254410117186518
# generated_set
# Kullback–Leibler divergence: 0.08750755112610888
# Overlap area: 0.7889710395859333
# total_used_note:
# ------------------------
# reference_set
# Kullback–Leibler divergence: 2.540116720253062
# Overlap area: 0.15547289147169893
# generated_set
# Kullback–Leibler divergence: 0.34648197203740116
# Overlap area: 0.614522388921026
# total_pitch_class_histogram:
# ------------------------
# reference_set
# Kullback–Leibler divergence: 0.9108121988053459
# Overlap area: 0.7946217526356666
# generated_set
# Kullback–Leibler divergence: 0.05716468508735415
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 10
#       8 print('generated_set')
# ...

# %%
from piano_transformer.utils.metrics import compare, oa, kld
from pathlib import Path

print("pitch:")
print("oa:", compare(Path("output/prompts"), Path("output/generated"), oa, "tokenizer.json", feature="pitch"))
print("kld:", compare(Path("output/prompts"), Path("output/generated"), kld, "tokenizer.json", feature="pitch"))
print("duration:")
print("oa:", compare(Path("output/prompts"), Path("output/generated"), oa, "tokenizer.json", feature="duration"))
print("kld:", compare(Path("output/prompts"), Path("output/generated"), kld, "tokenizer.json", feature="duration"))
print("velocity:")
print("oa:", compare(Path("output/prompts"), Path("output/generated"), oa, "tokenizer.json", feature="velocity"))
print("kld:", compare(Path("output/prompts"), Path("output/generated"), kld, "tokenizer.json", feature="velocity"))
# Out:
# pitch:
# oa: 0.8139427321957864
# kld: 0.08972915896008563
# duration:
# oa: None
# kld: None
# velocity:
# oa: None
# kld: None

# %%
from piano_transformer.utils.metrics import fmd

fmd(Path("output/prompts"), Path("output/generated"))
# Out:
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# c:\Users\Jonathan\Documents\piano-transformer\.venv\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Jonathan\.cache\huggingface\hub\models--FacebookAI--xlm-roberta-base. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...
